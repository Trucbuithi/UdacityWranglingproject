# %%
import pandas as pd
import numpy as np
import requests
import time
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import seaborn as sns

# %% [markdown]
# # Gather

# %% [markdown]
# ## Twitter archive

# %%
#read csv file
df1= pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# ## Image Predictions

# %%
#use request to download tsv file from a website
url ='https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

with open (url.split('/')[-1], mode = 'wb') as file:
    file.write(response.content)
    
#read downloaded file (tsv)

df2 = pd.read_csv('image-predictions.tsv', sep = ('\t'))

# %% [markdown]
# ## API Data

# %%
#read json file
df3= pd.read_json('tweet-json.txt', lines = True)

# %% [markdown]
# # Access

# %%
df1.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df1.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
df1['rating_numerator'].sort_values()
# Out:
# 315        0
# 1016       0
# 2335       1
# 2261       1
# 2338       1
#         ...
# 2074     420
# 188      420
# 189      666
# 313      960
# 979     1776
# Name: rating_numerator, Length: 2356, dtype: int64

# %%
df1['rating_denominator'].sort_values()
# Out:
# 313       0
# 2335      2
# 516       7
# 1576     10
# 1575     10
#        ...
# 1635    110
# 1779    120
# 1634    130
# 902     150
# 1120    170
# Name: rating_denominator, Length: 2356, dtype: int64

# %%
df1.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
df1.name.value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Cooper      11
# Lucy        11
#           ...
# Venti        1
# Duchess      1
# Meera        1
# Eriq         1
# Fiji         1
# Name: name, Length: 957, dtype: int64

# %%
df1.query('expanded_urls == "None" | tweet_id  == "None" | in_reply_to_status_id == "None"| in_reply_to_user_id == "None" | timestamp == "None" | source == "None" | text == "None" | retweeted_status_id == "None" | retweeted_status_user_id == "None" | retweeted_status_timestamp == "None"| expanded_urls  == "None"|rating_numerator == "None"|rating_denominator == "None"')
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df2.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
df2.tail()
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070        2       basset  0.555712    True    English_springer  0.225770
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df2.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.groupby(['tweet_id'])['jpg_url'].value_counts()
# Out:
# tweet_id            jpg_url
# 666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg    1
# 666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg    1
# 666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg    1
# 666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg    1
# 666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg    1
#                                                                       ..
# 891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg    1
# 891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg    1
# 891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg    1
# 892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg    1
# 892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg    1
# Name: jpg_url, Length: 2075, dtype: int64

# %%
df3.head()
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
#
#                                            full_text  truncated  \
# 0  This is Phineas. He's a mystical boy. Only eve...      False
# 1  This is Tilly. She's just checking pup on you....      False
# 2  This is Archie. He is a rare Norwegian Pouncin...      False
# 3  This is Darla. She commenced a snooze mid meal...      False
# 4  This is Franklin. He would like you to stop ca...      False
#
#   display_text_range                                           entities  \
# 0            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
# ...

# %%
df3.describe()
# Out:
#                  id        id_str  in_reply_to_status_id  \
# count  2.354000e+03  2.354000e+03           7.800000e+01
# mean   7.426978e+17  7.426978e+17           7.455079e+17
# std    6.852812e+16  6.852812e+16           7.582492e+16
# min    6.660209e+17  6.660209e+17           6.658147e+17
# 25%    6.783975e+17  6.783975e+17           6.757419e+17
# 50%    7.194596e+17  7.194596e+17           7.038708e+17
# 75%    7.993058e+17  7.993058e+17           8.257804e+17
# max    8.924206e+17  8.924206e+17           8.862664e+17
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               7.800000e+01         7.800000e+01
# mean                7.455079e+17         2.014171e+16
# std                 7.582492e+16         1.252797e+17
# min                 6.658147e+17         1.185634e+07
# 25%                 6.757419e+17         3.086374e+08
# 50%                 7.038708e+17         4.196984e+09
# 75%                 8.257804e+17         4.196984e+09
# ...

# %% [markdown]
# ### Quality
#
# #### df1
#  - tweet-id should be in str
#  - Timestamp in str format, should be in datetime.
#  - Erroneous datatypes (in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id ), should be in int instead of float, or maybe in str because we dont need to calculate anything with these collumns.
#  - rating_nominator and rating_denominator may have incorrect values.
#  - Name collumn has invalid values such as None, a.
#
# #### df2
#  - tweet-id should be in str
#
#
#
# #### df3
#  - All id collumns should be in str
#
#
# ### Tidiness
#
# #### df1
#  - 4 types of dogs (doggo,floofer,pupper,puppo) can be in the same collumn.
#  - Some non-nessessary collumns can be deleted.
#
#
# #### df2
# - Some non-nessessary collumns can be deleted.
# - Merge into one dataset.
#
# #### df3
# - Some non-nessessary collumns can be deleted.
# - Merge into one dataset.

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## Tidiness

# %%
#make copies of each dataframe to clean
df1_clean= df1.copy()
df2_clean= df2.copy()
df3_clean= df3.copy()

# %%
#first we need to merge 3 data into one dataframe
#change collumn id in df3_clean into tweet_id
df3_clean.rename(columns = {'id':'tweet_id'}, inplace = True)

# %%
#drop all unnessessary columns in df3_clean, only get 3 columns in df3_clean
df3_clean= df3_clean[['tweet_id', 'retweet_count','favorite_count']]
df3_clean.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %%
#merge 3 data tables into one
df_master= pd.merge(df1_clean, df2_clean, how = 'inner', on = ['tweet_id'] )
df_master= pd.merge(df_master, df3_clean, how = 'inner', on = ['tweet_id'] )
df_master
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2068  666049248165822465                    NaN                  NaN
# 2069  666044226329800704                    NaN                  NaN
# 2070  666033412701032449                    NaN                  NaN
# 2071  666029285002620928                    NaN                  NaN
# 2072  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %% [markdown]
# #### Define

# %% [markdown]
# Drop retweeted

# %% [markdown]
# #### Code

# %%
df_master = df_master[df_master['retweeted_status_id'].isnull()]
df_master
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2068  666049248165822465                    NaN                  NaN
# 2069  666044226329800704                    NaN                  NaN
# 2070  666033412701032449                    NaN                  NaN
# 2071  666029285002620928                    NaN                  NaN
# 2072  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %% [markdown]
# #### Check

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2072
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    1994 non-null   int64
#  1   in_reply_to_status_id       23 non-null     float64
#  2   in_reply_to_user_id         23 non-null     float64
#  3   timestamp                   1994 non-null   object
#  4   source                      1994 non-null   object
#  5   text                        1994 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               1994 non-null   object
#  10  rating_numerator            1994 non-null   int64
#  11  rating_denominator          1994 non-null   int64
#  12  name                        1994 non-null   object
# ...

# %% [markdown]
# #### Define

# %% [markdown]
# Remove retweeted columns

# %% [markdown]
# #### Code

# %%
df_master= df_master.drop('retweeted_status_id', axis =1)
df_master= df_master.drop('retweeted_status_user_id', axis =1)
df_master= df_master.drop('retweeted_status_timestamp', axis =1)

# %% [markdown]
# #### Check

# %%
df_master.shape
# Out:
# (1994, 27)

# %% [markdown]
# #### Define

# %% [markdown]
# Combine 4 dog types into one column

# %% [markdown]
# #### Code

# %%
dog = ['doggo', 'floofer', 'pupper', 'puppo']
list1= list(df_master.columns)
list2 = []
for x in list1:
    if x in dog:
        continue
    list2.append(x)
print(list2)
print(dog)
# Out:
# ['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp', 'source', 'text', 'expanded_urls', 'rating_numerator', 'rating_denominator', 'name', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'retweet_count', 'favorite_count']
# ['doggo', 'floofer', 'pupper', 'puppo']

# %%
# make 4 dog_types column become one column
df_master = df_master.melt(id_vars = list2, value_vars = dog, var_name = 'types', value_name = 'dog_type')
df_master
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 7971  666049248165822465                    NaN                  NaN
# 7972  666044226329800704                    NaN                  NaN
# 7973  666033412701032449                    NaN                  NaN
# 7974  666029285002620928                    NaN                  NaN
# 7975  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
#drop column types name
df_master = df_master.drop('types', 1)

# %%
# check that column types name is dropped 
df_master.shape
# Out:
# (7976, 24)

# %%
df_master
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 7971  666049248165822465                    NaN                  NaN
# 7972  666044226329800704                    NaN                  NaN
# 7973  666033412701032449                    NaN                  NaN
# 7974  666029285002620928                    NaN                  NaN
# 7975  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
df_master.dog_type.value_counts()
# Out:
# None       7659
# pupper      212
# doggo        74
# puppo        23
# floofer       8
# Name: dog_type, dtype: int64

# %%
df_master.groupby(df_master['tweet_id'])['dog_type'].value_counts().sort_values()
# Out:
# tweet_id            dog_type
# 673707060090052608  pupper      1
# 817777686764523521  doggo       1
#                     pupper      1
# 756526248105566208  doggo       1
# 701545186879471618  pupper      1
#                                ..
# 687807801670897665  None        4
# 687664829264453632  None        4
# 687494652870668288  None        4
# 688908934925697024  None        4
# 892420643555336193  None        4
# Name: dog_type, Length: 2311, dtype: int64

# %%
#sort dog_type in order 
df_master = df_master.sort_values('dog_type')
df_master
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 5315  683030066213818368                    NaN                  NaN
# 5313  683098815881154561                    NaN                  NaN
# 5310  683357973142474752                    NaN                  NaN
# 5309  683391852557561860                    NaN                  NaN
# ...                  ...                    ...                  ...
# 6463  790946055508652032                    NaN                  NaN
# 6087  867421006826221569                    NaN                  NaN
# 6044  878776093423087618                    NaN                  NaN
# 6279  825535076884762624                    NaN                  NaN
# 6764  743253157753532416                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 5315  2016-01-01 21:00:32 +0000
# 5313  2016-01-02 01:33:43 +0000
# ...

# %%
#keep only one tweet_id for dog_type and we get the last one.
df_master = df_master.sort_values('dog_type').drop_duplicates('tweet_id', keep = 'last')
df_master
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 4655  757725642876129280                    NaN                  NaN
# 4705  750117059602808832                    NaN                  NaN
# 4706  750101899009982464                    NaN                  NaN
# 4654  757741869644341248                    NaN                  NaN
# 4651  758405701903519748                    NaN                  NaN
# ...                  ...                    ...                  ...
# 5996  889531135344209921                    NaN                  NaN
# 6281  825026590719483904                    NaN                  NaN
# 6279  825535076884762624                    NaN                  NaN
# 6481  787717603741622272                    NaN                  NaN
# 6764  743253157753532416                    NaN                  NaN
#
#                       timestamp  \
# 4655  2016-07-25 23:54:05 +0000
# 4705  2016-07-05 00:00:18 +0000
# 4706  2016-07-04 23:00:03 +0000
# ...

# %% [markdown]
# #### Check

# %%
df_master.shape
# Out:
# (1994, 24)

# %% [markdown]
# #### Define
# Delete unnecessary columns

# %% [markdown]
# #### Code

# %%
df_master.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'jpg_url', 'img_num', 'p1', 'p1_conf',
#        'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog',
#        'retweet_count', 'favorite_count', 'dog_type'],
#       dtype='object')

# %%
df_master= df_master.drop('img_num', axis =1)
df_master= df_master.drop('p1', axis =1)
df_master= df_master.drop('p1_conf', axis =1)
df_master= df_master.drop('p1_dog', axis =1)
df_master= df_master.drop('p2', axis =1)
df_master= df_master.drop('p2_conf', axis =1)
df_master= df_master.drop('p2_dog', axis =1)
df_master= df_master.drop('p3', axis =1)
df_master= df_master.drop('p3_conf', axis =1)
df_master= df_master.drop('p3_dog', axis =1)

# %% [markdown]
# #### Check

# %%
df_master.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'jpg_url', 'retweet_count',
#        'favorite_count', 'dog_type'],
#       dtype='object')

# %% [markdown]
# ## Quality

# %%
df_master.head(1)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 4655  757725642876129280                    NaN                  NaN
#
#                       timestamp  \
# 4655  2016-07-25 23:54:05 +0000
#
#                                                  source  \
# 4655  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 4655  This is Beckham. He fell asleep at the wheel. ...
#
#                                           expanded_urls  rating_numerator  \
# 4655  https://twitter.com/dog_rates/status/757725642...                11
#
#       rating_denominator     name  \
# 4655                  10  Beckham
#
#                                               jpg_url  retweet_count  \
# 4655  https://pbs.twimg.com/media/CoP7c4bWcAAr55g.jpg           1391
#
#       favorite_count dog_type
# 4655            5022     None

# %% [markdown]
# #### Define
#
# Change datatype of tweet_id,in_reply_to_status_id,in_reply_to_user_id , dog_type and timestamp

# %% [markdown]
# #### Code

# %%
df_master.tweet_id = df_master.tweet_id.astype(str)
df_master.in_reply_to_status_id  = df_master.in_reply_to_status_id .astype(str)
df_master.in_reply_to_user_id= df_master.in_reply_to_user_id.astype(str)

# %%
df_master.timestamp= pd.to_datetime(df_master.timestamp)

# %%
df_master.dog_type=df_master.dog_type.astype('category')

# %% [markdown]
# #### Check

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 4655 to 6764
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               1994 non-null   object
#  1   in_reply_to_status_id  1994 non-null   object
#  2   in_reply_to_user_id    1994 non-null   object
#  3   timestamp              1994 non-null   datetime64[ns, UTC]
#  4   source                 1994 non-null   object
#  5   text                   1994 non-null   object
#  6   expanded_urls          1994 non-null   object
#  7   rating_numerator       1994 non-null   int64
#  8   rating_denominator     1994 non-null   int64
#  9   name                   1994 non-null   object
#  10  jpg_url                1994 non-null   object
#  11  retweet_count          1994 non-null   int64
#  12  favorite_count         1994 non-null   int64
#  13  dog_type               1994 non-null   category
# ...

# %% [markdown]
# #### Define
#
# Change html source to easy text to understand

# %% [markdown]
# #### Code

# %%
#check content of many sources
df_master.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     1955
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       28
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
#change html links to short texts
df_master.source= df_master.source.str.replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'Twitter for iPhone')
df_master.source= df_master.source.str.replace('<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'Twitter Web Client')
df_master.source = df_master.source.str.replace('<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'TweetDeck')

# %% [markdown]
# #### Check

# %%
df_master.source.value_counts()
# Out:
# Twitter for iPhone    1955
# Twitter Web Client      28
# TweetDeck               11
# Name: source, dtype: int64

# %%
#change source type to category 
df_master.source.astype('category')
# Out:
# 4655    Twitter for iPhone
# 4705    Twitter for iPhone
# 4706    Twitter for iPhone
# 4654    Twitter for iPhone
# 4651    Twitter for iPhone
#                ...
# 5996    Twitter for iPhone
# 6281    Twitter for iPhone
# 6279    Twitter for iPhone
# 6481    Twitter for iPhone
# 6764    Twitter for iPhone
# Name: source, Length: 1994, dtype: category
# Categories (3, object): ['TweetDeck', 'Twitter Web Client', 'Twitter for iPhone']

# %%
df_master.source.value_counts()
# Out:
# Twitter for iPhone    1955
# Twitter Web Client      28
# TweetDeck               11
# Name: source, dtype: int64

# %% [markdown]
# #### Define
#
# Display full text column

# %% [markdown]
# #### Code

# %%
pd.options.display.max_colwidth = 10000

# %% [markdown]
# #### Check

# %%
df_master.head(1)
# Out:
#                 tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 4655  757725642876129280                   nan                 nan
#
#                      timestamp              source  \
# 4655 2016-07-25 23:54:05+00:00  Twitter for iPhone
#
#                                                                                                                                              text  \
# 4655  This is Beckham. He fell asleep at the wheel. Very churlish. Looks to have a backpup driver tho. That's good. 11/10 https://t.co/rptsOm73Wr
#
#                                                                                                                         expanded_urls  \
# 4655  https://twitter.com/dog_rates/status/757725642876129280/photo/1,https://twitter.com/dog_rates/status/757725642876129280/photo/1
#
#       rating_numerator  rating_denominator     name  \
# 4655                11                  10  Beckham
#
# ...

# %% [markdown]
# #### Define
# Remove replies

# %% [markdown]
# #### Code

# %%
df_master.in_reply_to_status_id.value_counts()
# Out:
# nan                      1971
# 6.671521640794235e+17       2
# 6.678064545737605e+17       1
# 8.55818117272019e+17        1
# 7.468859193875743e+17       1
# 7.291135312709919e+17       1
# 7.03255935813288e+17        1
# 6.914168664520827e+17       1
# 6.717299066283418e+17       1
# 7.030419496500347e+17       1
# 6.75349384339542e+17        1
# 6.747522332008202e+17       1
# 6.715610021362811e+17       1
# 6.70668383499735e+17        1
# 7.33109485275861e+17        1
# 6.842228683355054e+17       1
# 6.754971033223864e+17       1
# 7.590995235327795e+17       1
# 6.749998076819087e+17       1
# 6.747933991411466e+17       1
# 6.844810745593815e+17       1
# 6.75707330206548e+17        1
# 6.920419346894029e+17       1
# Name: in_reply_to_status_id, dtype: int64

# %%
df_master=df_master.query('in_reply_to_status_id == "nan"')

# %% [markdown]
# #### Check

# %%
df_master.shape
# Out:
# (1971, 14)

# %%
#drop in_reply_to_status_id and in_reply_to_user_id
df_master= df_master.drop('in_reply_to_status_id', axis =1)

# %%
df_master = df_master.drop('in_reply_to_user_id', axis =1)

# %%
df_master.head()
# Out:
#                 tweet_id                 timestamp              source  \
# 4655  757725642876129280 2016-07-25 23:54:05+00:00  Twitter for iPhone
# 4705  750117059602808832 2016-07-05 00:00:18+00:00  Twitter for iPhone
# 4706  750101899009982464 2016-07-04 23:00:03+00:00  Twitter for iPhone
# 4654  757741869644341248 2016-07-26 00:58:34+00:00  Twitter for iPhone
# 4651  758405701903519748 2016-07-27 20:56:24+00:00  Twitter for iPhone
#
#                                                                                                                                               text  \
# 4655   This is Beckham. He fell asleep at the wheel. Very churlish. Looks to have a backpup driver tho. That's good. 11/10 https://t.co/rptsOm73Wr
# 4705                                   This is Calvin. He just loves America so much. 10/10 would roll around in flag with https://t.co/RXdzWaCQHm
# ...

# %% [markdown]
# #### Define
#
# Remove html from text

# %% [markdown]
# #### Code

# %%
def remove_last_line_from_text(s):
    return s[:s.find('http')]

df_master.text= df_master.text.apply(remove_last_line_from_text)

# %% [markdown]
# #### Check

# %%
df_master.text.head(20)
# Out:
# 4655     This is Beckham. He fell asleep at the wheel. Very churlish. Looks to have a backpup driver tho. That's good. 11/10
# 4705                                     This is Calvin. He just loves America so much. 10/10 would roll around in flag with
# 4706    Meet Lilah. She agreed on one quick pic. Now she'd like to go mentally prepare for the onslaught of fireworks. 11/10
# 4654                                          This is Leonard. He hides in bushes to escape his problems. 10/10 relatable af
# 4651                                                    This is Odie. He falls asleep wherever he wants. Must be nice. 10/10
# 4688            This is Brody. He's a lifeguard. Always prepared for rescue. 12/10 would fake drown just to get saved by him
# 4689                                      This is Ruby. Her ice cube is melting. She doesn't know what to do about it. 11/10
# ...

# %% [markdown]
# #### Define
# Make year, month, day_of_week column

# %% [markdown]
# #### Code

# %%
df_master['year'] = df_master['timestamp'].dt.year
df_master['month'] = df_master['timestamp'].dt.month
df_master['day_of_week']= df_master['timestamp'].dt.weekday

# %%
df_master['month'].replace(1, 'January', inplace=True)
df_master['month'].replace(2, 'February', inplace=True)
df_master['month'].replace(3, 'March', inplace=True)
df_master['month'].replace(4, 'April', inplace=True)
df_master['month'].replace(5, 'May', inplace=True)
df_master['month'].replace(6, 'June', inplace=True)
df_master['month'].replace(7, 'July', inplace=True)
df_master['month'].replace(8, 'August', inplace=True)
df_master['month'].replace(9, 'September', inplace=True)
df_master['month'].replace(10, 'October', inplace=True)
df_master['month'].replace(11, 'November', inplace=True)
df_master['month'].replace(12, 'December', inplace=True)

# %%
df_master['day_of_week'].replace(0, 'Monday', inplace=True)
df_master['day_of_week'].replace(1, 'Tuesday', inplace=True)
df_master['day_of_week'].replace(2, 'Wednesday', inplace=True)
df_master['day_of_week'].replace(3, 'Thursday', inplace=True)
df_master['day_of_week'].replace(4, 'Friday', inplace=True)
df_master['day_of_week'].replace(5, 'Saturday', inplace=True)
df_master['day_of_week'].replace(6, 'Sunday', inplace=True)

# %% [markdown]
# #### Check

# %%
df_master.iloc[:,10:]
# Out:
#       favorite_count dog_type  year    month day_of_week
# 4655            5022     None  2016     July      Monday
# 4705            4740     None  2016     July     Tuesday
# 4706            3344     None  2016     July      Monday
# 4654            7613     None  2016     July     Tuesday
# 4651            5756     None  2016     July   Wednesday
# ...              ...      ...   ...      ...         ...
# 5996           15359    puppo  2017     July      Monday
# 6281            7020    puppo  2017  January      Friday
# 6279           56413    puppo  2017  January      Sunday
# 6481           11416    puppo  2016  October      Sunday
# 6764            4624    puppo  2016     June    Thursday
#
# [1971 rows x 5 columns]

# %% [markdown]
# #### Define
#
# Create dog name from text column and create new dog name column

# %% [markdown]
# #### Code

# %%
def get_dog_name(x):
    return x[:x.find('.')]

text = df_master.text
dog_name = text.apply(get_dog_name)

# %%
df_master['dog_name']= dog_name.str.rsplit(' ', 1).str[-1]

# %%
df_master['dog_name'].value_counts()
# Out:
# here            60
# dogs            33
# dog             24
# 12/10           18
# pupper          15
#                 ..
# Rinna            1
# Pancake          1
# Chesney          1
# Ozzie            1
# Cleopatricia     1
# Name: dog_name, Length: 1274, dtype: int64

# %%
#drop old name column
df_master= df_master.drop('name', axis=1)

# %%
dog_name =[]
for name in list(df_master['dog_name']):
    if name.istitle():
        dog_name.append(name)
    else:
        dog_name.append('None')
df_master['dog_name']= dog_name

# %% [markdown]
# #### Check

# %%
df_master['dog_name'].value_counts().sort_values()
# Out:
# We           1
# Corey        1
# Mairi        1
# Champ        1
# Glenn        1
#           ...
# Lucy         9
# Cooper      10
# Oliver      11
# Charlie     13
# None       558
# Name: dog_name, Length: 975, dtype: int64

# %% [markdown]
# #### Define
#
# Create count_url column

# %% [markdown]
# #### Code

# %%
count_url= df_master.expanded_urls.str.split(',').str.len()

# %%
df_master['count_url']= count_url

# %% [markdown]
# #### Check

# %%
df_master['count_url'].value_counts().sort_values()
# Out:
# 5       8
# 4     105
# 3     110
# 2     282
# 1    1466
# Name: count_url, dtype: int64
